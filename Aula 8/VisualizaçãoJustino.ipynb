# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
dados =  pd.read_csv('base/HRDataset_v14.csv')
dados.head(2)
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# 0  Michael Albert       22.0          LinkedIn          Exceeds
# 1      Simon Roup        4.0            Indeed      Fully Meets
#
#    EngagementSurvey EmpSatisfaction SpecialProjectsCount  \
# 0              4.60               5                    0
# 1              4.96               3                    6
#
#   LastPerformanceReview_Date DaysLateLast30 Absences
# 0                  1/17/2019              0        1
# ...

# %%
#Executar estatísticas descritivas básicas no Python.
dados.describe()
# Out:
#               EmpID   MarriedID  MaritalStatusID    GenderID  EmpStatusID  \
# count    311.000000  311.000000       311.000000  311.000000   311.000000
# mean   10156.000000    0.398714         0.810289    0.434084     2.392283
# std       89.922189    0.490423         0.943239    0.496435     1.794383
# min    10001.000000    0.000000         0.000000    0.000000     1.000000
# 25%    10078.500000    0.000000         0.000000    0.000000     1.000000
# 50%    10156.000000    0.000000         1.000000    0.000000     1.000000
# 75%    10233.500000    1.000000         1.000000    1.000000     5.000000
# max    10311.000000    1.000000         4.000000    1.000000     5.000000
#
#            DeptID  PerfScoreID  FromDiversityJobFairID         Salary  \
# count  311.000000   311.000000              311.000000     311.000000
# mean     4.610932     2.977492                0.093248   69020.684887
# std      1.083487     0.587072                0.291248   25156.636930
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %%
mpl.style.use('bmh')

# %%
tabela =  pd.DataFrame(dados)
#tabela  = tabela.loc[(tabela['Salary'] > 0,('Salary'))]
tabela
tabelas_ajustada = tabela.groupby(['Position']).size().reset_index(name='Total_Salarios')
tabelas_ajustada
# Out:
#                         Position  Total_Salarios
# 0                   Accountant I               3
# 1       Administrative Assistant               3
# 2             Area Sales Manager              27
# 3                   BI Developer               4
# 4                    BI Director               1
# 5                            CIO               1
# 6                   Data Analyst               7
# 7                  Data Analyst                1
# 8                 Data Architect               1
# 9         Database Administrator               5
# 10        Director of Operations               1
# 11             Director of Sales               1
# 12          Enterprise Architect               1
# 13                   IT Director               1
# 14               IT Manager - DB               2
# 15            IT Manager - Infra               1
# 16          IT Manager - Support               1
# 17                    IT Support               8
# ...

# %%
#Fazer um histograma com salários. Quais faixas salariais são as mais populares?
sns.set()
fig, ax = plt.subplots(figsize=(20,4))
plt.xticks(rotation=90)#Legenda na vertical
ax.bar(tabelas_ajustada['Position'], tabelas_ajustada['Total_Salarios'])
ax.set_title('Salario mais Popular')
ax.set_ylabel('Quantidade de Salarios')
ax.set_xlabel('Profissao')
# Out:
# Text(0.5, 0, 'Profissao')

# %%
#Fazer um gráfico de violino com salários, discriminados por gênero.

# %%
#dados_genero = dados.groupby(['Sex']).size().reset_index(name='qtd_genero')
#dados_genero2 = dados.groupby(['Sex'])['Salary'].sum().reset_index(name='total_salario')
#pd.concat([dados_genero, dados_genero2],ignore_index = True)
#dados_genero3 = pd.merge(dados_genero2, dados_genero, on = 'Sex')
#dados_genero3
dados
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %%
ax = sns.catplot(data=dados, kind='violin', x='Sex', y='Salary', hue='Sex', split=True)
ax.set(xlabel='Salario', ylabel='Genero', title='Salario Por genero')

# %%
#Traçar a série temporal correspondente à data de contratação (DateofHire)

# %%
dados['DateofHire']= pd.to_datetime(dados['DateofHire'])

dados_date = dados.groupby(['DateofHire']).size().reset_index(name='qtd')
dados_date
# Out:
#     DateofHire  qtd
# 0   2006-01-09    1
# 1   2007-06-25    1
# 2   2007-11-05    1
# 3   2008-01-07    1
# 4   2008-09-02    1
# ..         ...  ...
# 96  2017-01-07    1
# 97  2017-02-10    1
# 98  2017-02-15    2
# 99  2017-04-20    2
# 100 2018-07-09    1
#
# [101 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize=(20,4))
ax.plot(dados_date['DateofHire'], dados_date['qtd'])

ax.grid(True, linestyle='-.')
ax.tick_params(labelcolor='r', labelsize='medium', width=3)

plt.show()
